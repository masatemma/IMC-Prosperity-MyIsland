# %%
import pandas as pd
df = pd.read_csv('results/example_trader_results.csv', sep=(';'))
amethysts_data = df[df['product'] == "AMETHYSTS"]
amethysts_data
# Out:
#       day  timestamp    product  bid_price_1  bid_volume_1  bid_price_2  \
# 0      -2          0  AMETHYSTS        10002             1       9996.0
# 2      -2        100  AMETHYSTS         9996             2       9995.0
# 5      -2        200  AMETHYSTS         9995            20          NaN
# 6      -2        300  AMETHYSTS         9996             2       9995.0
# 8      -2        400  AMETHYSTS         9996             2       9995.0
# ...   ...        ...        ...          ...           ...          ...
# 3991   -2     199500  AMETHYSTS        10002             1       9996.0
# 3992   -2     199600  AMETHYSTS         9996             1       9995.0
# 3995   -2     199700  AMETHYSTS         9998             8       9996.0
# 3997   -2     199800  AMETHYSTS         9995            21          NaN
# 3999   -2     199900  AMETHYSTS         9996             2       9995.0
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
# define data values
amethysts_data = df[df['product'] == "AMETHYSTS"]
amethysts_data

x_sequence = range(1, len(amethysts_data) + 1)

plt.figure(figsize=(10, 6))
plt.plot(x_sequence, amethysts_data['mid_price'], label='AMETHYSTS Mid Price')
plt.ylim([9990, 10010])
# Out:
# (9990.0, 10010.0)

# %%
starfruit_data = df[df['product'] == "STARFRUIT"]
starfruit_data

x_sequence_starfruit = range(1, len(starfruit_data) + 1)

# Plotting the graph
plt.figure(figsize=(10, 6))
plt.plot(x_sequence_starfruit, starfruit_data['mid_price'], label='STARFRUIT Mid Price')
